# %% [markdown]
# <a href="https://colab.research.google.com/github/joaoavelaar/FabricaDeSoftware/blob/main/FabricaDeSoftware_Dia1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  ***Tema:*** Titanic
#
#
# ---
#
#
# **Questionamento do problema:** A final qual foi a causa do naufrágio do titanic e quantas pessoas morreram?
#
#
#
#
# 1. Quantas pessoas perderam a vida no naufrágio do Titanic?
# 2. Quais foram os principais fatores que levaram ao naufrágio do Titanic?
# 3. Onde exatamente o Titanic afundou?
# 4. Qual foi a rota planejada para a viagem do Titanic?
# 5. Quantos passageiros e tripulantes estavam a bordo do Titanic no momento do naufrágio?
# 6. O Titanic tinha botes salva-vidas suficientes para todos a bordo?
# 7. Houve algum aviso prévio sobre a presença de icebergs na rota do Titanic?
# 8. Qual foi a resposta inicial da comunidade internacional ao desastre do Titanic?
# 9. Existem teorias controversas sobre o naufrágio do Titanic?
# 10. Como o naufrágio do Titanic impactou os regulamentos de segurança marítima?
#
# ---

# %%
# Visualização do grafico do dataset titanic

# Importando as bibliotecas
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
# Lendo o arquivo CSV.
df_titanic = pd.read_csv("Titanic.csv")

# %%
df_titanic.head(5)
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0            1         0       3    Male  22.0      1      0   7.2500
# 1            2         1       1  female  38.0      1      0  71.2833
# 2            3         1       3  female  26.0      0      0   7.9250
# 3            4         1       1  female  35.0      1      0  53.1000
# 4            5         0       3    Male  35.0      0      0   8.0500
#
#    Embarked
# 0         3
# 1         1
# 2         3
# 3         3
# 4         3

# %%
# Exibindo as ultimas linhas do DataFrame Titanic.
df_titanic.tail(5)
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch   Fare  \
# 884          887         0       2    Male  27.0      0      0  13.00
# 885          888         1       1  female  19.0      0      0  30.00
# 886          889         0       3  female  60.0      1      2  23.45
# 887          890         1       1    Male  26.0      0      0  30.00
# 888          891         0       3    Male  32.0      0      0   7.75
#
#      Embarked
# 884         3
# 885         3
# 886         3
# 887         1
# 888         2

# %%
# O uso regular do Matplotlib para mostrar o "Gráfico de Barra" (Sexo e Idade).
df_titanic.groupby(['Sex'])['Age'].count().plot(kind='bar')
# Out:
# <Axes: xlabel='Sex'>
